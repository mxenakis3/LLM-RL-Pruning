# %%
# %load_ext autoreload
# %autoreload 2

# %%
# IMPORT DESIRED INTERACTION CLASS AND CONFIGURATION
import sys
import os
import numpy as np

# Get the parent directory (where `configs/` and `interactions/` are located)
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Add it to sys.path
sys.path.append(parent_dir)

import torch
# if torch.cuda.is_available():
#     torch.set_default_device('cuda')
# else:
#     torch.set_default_device('cpu')

# Now you should be able to import
from interactions import ppo_interaction as ppo
# from configs.interaction_configs.ppo_interaction_configs import ppo_interaction_config
# from configs.interaction_configs.ppo_interaction_configs import ppo_interaction_texasholdem_config
from configs.ppo_configs import ppo_interaction_config_texas, texas_holdem_config, actor_configs_texas, critic_configs_texas
from configs.llm_configs import texas_holdem_llm_agent_configs
# from configs.agent_configs.a_ppo_agents import actor_configs, critic_configs
# Out:
# INFO 04-28 12:08:46 [__init__.py:239] Automatically detected platform cuda.

# %%
ppo_interaction = ppo.PPO_interaction(interaction_configs=ppo_interaction_config_texas,
                    env_configs = texas_holdem_config,
                      actor_configs = actor_configs_texas,
                      critic_configs = critic_configs_texas,
                      llm_configs=texas_holdem_llm_agent_configs
                  )

train_scores, trained_agents = ppo_interaction.train_multiagent()
print(train_scores)
# Out:
# 🖥  Using device: cuda
# self obs size: 76
# INFO 04-28 12:08:57 [config.py:689] This model supports multiple tasks: {'classify', 'embed', 'generate', 'reward', 'score'}. Defaulting to 'generate'.
# INFO 04-28 12:08:57 [config.py:1901] Chunked prefill is enabled with max_num_batched_tokens=16384.
# WARNING 04-28 12:08:58 [utils.py:2304] We must use the `spawn` multiprocessing start method. Overriding VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/getting_started/troubleshooting.html#python-multiprocessing for more information. Reason: CUDA is initialized
# INFO 04-28 12:09:02 [__init__.py:239] Automatically detected platform cuda.
# INFO 04-28 12:09:04 [core.py:61] Initializing a V1 LLM engine (v0.8.4) with config: model='deepseek-ai/deepseek-llm-7b-chat', speculative_config=None, tokenizer='deepseek-ai/deepseek-llm-7b-chat', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='auto', reasoning_backend=None), observability_config=ObservabilityConfig(show_hidden_metrics=False, otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=None, served_model_name=deepseek-ai/deepseek-llm-7b-chat, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":3,"custom_ops":["none"],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output"],"use_inductor":true,"compile_sizes":[],"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":512}
# WARNING 04-28 12:09:05 [utils.py:2444] Methods determine_num_available_blocks,device_config,get_cache_block_size_bytes,initialize_cache not implemented in <vllm.v1.worker.gpu_worker.Worker object at 0x15544a477310>
# INFO 04-28 12:09:06 [parallel_state.py:959] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0
# INFO 04-28 12:09:06 [cuda.py:221] Using Flash Attention backend on V1 engine.
# INFO 04-28 12:09:06 [gpu_model_runner.py:1276] Starting to load model deepseek-ai/deepseek-llm-7b-chat...
# WARNING 04-28 12:09:06 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# INFO 04-28 12:09:06 [weight_utils.py:265] Using model weights format ['*.bin']
# Loading pt checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# Loading pt checkpoint shards:  50% Completed | 1/2 [00:03<00:03,  3.58s/it]
# Loading pt checkpoint shards: 100% Completed | 2/2 [00:04<00:00,  2.28s/it]
# Loading pt checkpoint shards: 100% Completed | 2/2 [00:04<00:00,  2.48s/it]
# INFO 04-28 12:09:11 [loader.py:458] Loading weights took 4.96 seconds
# INFO 04-28 12:09:11 [gpu_model_runner.py:1291] Model loading took 12.8726 GiB and 5.528829 seconds
# INFO 04-28 12:09:19 [backends.py:416] Using cache directory: /home/hice1/mxenakis3/.cache/vllm/torch_compile_cache/d2ef6609b2/rank_0_0 for vLLM's torch.compile
# INFO 04-28 12:09:19 [backends.py:426] Dynamo bytecode transform time: 7.94 s
# INFO 04-28 12:09:20 [backends.py:115] Directly load the compiled graph for shape None from the cache
# INFO 04-28 12:09:25 [monitor.py:33] torch.compile takes 7.94 s in total
# INFO 04-28 12:09:26 [kv_cache_utils.py:634] GPU KV cache size: 116,560 tokens
# INFO 04-28 12:09:26 [kv_cache_utils.py:637] Maximum concurrency for 4,096 tokens per request: 28.46x
# INFO 04-28 12:09:40 [gpu_model_runner.py:1626] Graph capturing finished in 14 secs, took 0.58 GiB
# INFO 04-28 12:09:40 [core.py:163] init engine (profile, create kv cache, warmup model) took 28.43 seconds
# INFO 04-28 12:09:40 [core_client.py:435] Core engine process 0 ready.
#   0%|          | 0/10 [00:00<?, ?it/s]
# INFO 04-28 12:09:40 [chat_utils.py:396] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# 100%|██████████| 10/10 [00:25<00:00,  2.52s/it]
# [np.float64(-0.5), np.float64(3.0), np.float64(-0.5), np.float64(-1.0), np.float64(-0.5), np.float64(1.0), np.float64(0.5), np.float64(-3.0), np.float64(-1.0), np.float64(-1.0)]

# %%
test_scores = ppo_interaction.test_multiagent(trained_agents)
print(test_scores)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 416.35it/s]
# [np.float64(-5.0), np.float64(1.0), np.float64(1.0), np.float64(5.0), np.float64(1.0)]

# %%
import matplotlib.pyplot as plt

window = 1
rolling = np.convolve(train_scores,
                      np.ones(window)/window, mode='valid')
plt.plot(rolling)
plt.axhline(0,color='k',ls='--')
plt.ylabel('BB / hand ({}-hand MA)'.format(window))
plt.xlabel('Hand number')
plt.show()

window = 500
rolling = np.convolve(test_scores,
                      np.ones(window)/window, mode='valid')
plt.plot(rolling)
plt.axhline(0,color='k',ls='--')
plt.ylabel('BB / hand ({}-hand MA)'.format(window))
plt.xlabel('Hand number')
plt.show()


fig, (ax1, ax2)  = plt.subplots(1, 2)
ax1.set_title("Training Scores")
ax1.set_xlabel("Episodes")
ax1.set_ylabel("Score")
ax1.plot(train_scores)
ax1.grid(True)

ax2.set_title("Testing Scores")
ax2.set_xlabel("Episodes")
ax2.set_ylabel("Score")
ax2.plot(test_scores)
ax2.grid(True)

plt.tight_layout()

plt.show()
